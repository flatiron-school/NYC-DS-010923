# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:200%;
#            font-family:Arial;letter-spacing:0.5px">
#
# <p width = 20%, style="padding: 10px;
#               color:white;">
# Convolutional Neural Networks
#
# </p>
# </div>
#
# Data Science Cohort Live NYC March 2023
# <p>Phase 4: Topic 39</p>
# <br>
# <br>
#
# <div align = "right">
# <img src="Images/flatiron-school-logo.png" align = "right" width="200"/>
# </div>

# %%
from PIL import Image, ImageOps
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Convolution Neural Networks (CNNs)
# - An architecture designed for visual pattern recognition
# - Classification/regression on image data

# %% [markdown]
# Why a new architecture?

# %%
dogey = Image.open("Images/dog.jpg")
dogey_grayscale = ImageOps.grayscale(dogey)
display(dogey_grayscale)
# Out:
# <PIL.Image.Image image mode=L size=496x503>

# %%
dg_array = np.array(dogey_grayscale)
dg_array
# Out:
# array([[154, 150, 149, ..., 217, 216, 216],
#        [153, 149, 147, ..., 217, 216, 216],
#        [150, 146, 145, ..., 217, 216, 216],
#        ...,
#        [214, 214, 213, ..., 127, 128, 129],
#        [214, 213, 213, ..., 120, 122, 123],
#        [213, 213, 212, ..., 116, 118, 120]], dtype=uint8)

# %% [markdown]
# Pixel values: high local correlations across columns/rows.

# %% [markdown]
# The problem with standard neural network (aka multilayer perceptron network):
# - let's flatten the doge and inspect features.

# %%
flattened_input = np.ravel(dg_array)
len(flattened_input)
# Out:
# 249488

# %% [markdown]
# All those features go in to MLP:

# %% [markdown]
# <center><img src = "Images/mlp_image.jfif" width =600/></center>
# <center> Number of weights to first layer: huge

# %% [markdown]
# Treats features as independent:
# - Large number of features.
# - Dense connections: large number of weights to tune
# - Weights trying to learn pixel-level correlations

# %% [markdown]
# Not a good idea. Too specific.

# %% [markdown]
# Want to start model at a much higher level of feature abstraction

# %% [markdown]
# #### Building up the convolutional network

# %% [markdown]
# <center><img src = "Images/mlp-convolution-transform.webp" width = 500>

# %% [markdown]
# Cutting connections:
# - not all pixel-pixel interactions relevant.
# - only pass neighboring pixels into given node at next layer.
#
# **Keeps information local**

# %% [markdown]
# <img src = "Images/convolution-mlp-mapping.webp" >

# %% [markdown]
# Full computation corresponds to **convolution**
#
# $$ \begin{bmatrix}
# x_{11} & x_{12} & x_{13} \\
# x_{21} & x_{22} & x_{23} \\
# x_{31} & x_{32} & x_{33}
# \end{bmatrix} *
# \begin{bmatrix}
# w_1 & w_2 \\
# w_3 & w_4
# \end{bmatrix} = \\
# \begin{bmatrix}
# w_1x_{11} + w_2x_{12} + w_3x_{21} + w_4x_{22} & w_1x_{12} + w_2x_{13} + w_3x_{22} + w_4x_{23} \\
# w_1x_{21} + w_2x_{22} + w_3x_{31} + w_4x_{32} & w_1 x_{22} + w_2x_{23} + w_3x_{32} + w_4x_{33}
# \end{bmatrix}$$

# %% [markdown]
# <center><img src = "Images/convolution-mlp-mapping.webp" width = 400 ></center>

# %% [markdown]
# Single node: element-wise multiplication and add them up.
# - A dot product between shared weights and relevant local inputs.

# %% [markdown]
# Convolution in non-flattened output representation:
# - Sliding window with element-wise multiplication/sum
# - Creates new image (2D matrix).

# %% [markdown]
# <center><img src = "Images/convolution.gif" ></center>

# %% [markdown]
# <center><img src = "Images/convolution-mlp-mapping.webp" width = 400 ></center>

# %% [markdown]
# <center><img src = "Images/filter.gif" ></center>

# %% [markdown]
# <center><img src = "Images/stride1.gif" ></center>

# %% [markdown]
# <center><img src = "Images/stride2.gif" ></center>

# %% [markdown]
# # Padding

# %% [markdown]
# <center><img src = "Images/paddingwithstride1.gif" ></center>

# %% [markdown]
# Why applying same weights for the different computations?

# %% [markdown]
# **Weight sharing:**
#
# Idea is that same set of weight patterns useful throughout image:
# - the same kinds of correlations keep showing up across different local regions.

# %% [markdown]
# <img src = "Images/convolution-mlp-mapping.webp" >

# %% [markdown]
# Learned weights acts as filter:
# - regions with no vertical edge are zero.
# - regions with vertical edge register value.
# - useful in many local areas of image
#
# **Same weight set applied to many local areas**

# %% [markdown]
# <img src = "Images/edge_detector_large.png" >

# %% [markdown]
# Other useful lower-level image features (benefiting from weight sharing):
#
# - Corner/special points
# - region/blob detection

# %% [markdown]
# <img src = "Images/corner_blobs.jpg" >

# %% [markdown]
# Much higher level features:
# - don't need to model pixel level structure

# %% [markdown]
# With colors we have three color dimensions (R/G/B):
# - Filter has three channels (R/G/B)
# - R channel applies a weight set to red intensity pixel values
# - G channel applies another weight set to green, ...

# %% [markdown]
# - Element-wise multiplication/addition channel-wise
# - Add result from all channels together.
#
# <img src = "Images/convwithcolor.png" >

# %% [markdown]
# - Can manually construct sets of filters and feature engineer.
# - But main idea of CNN is to *learn* these filters.
# - Given weight matrix feature engineers: CNN learning image feature extraction.

# %% [markdown]
# Typically, want to learn multiple filters at the same time:
# - Apply each filter/convolve on inputs seperately.
# - Creates stacked output (3D numpy array)

# %% [markdown]
# <img src = "Images/conv_manyfilters_expanded.jpg" width = 300/>

# %% [markdown]
# Multiple filters with colors:
# - Each filter has number of channels
# - Equaling depth of input layer.

# %% [markdown]
# Depth of output is equal to number of filters.

# %% [markdown]
# <img src = "Images/convcolormultifilters.png"  >

# %% [markdown]
# After each convolution operation:
# - apply nonlinear activation to output elementwise.

# %% [markdown]
# <img src = "Images/conv_activation.png" >

# %% [markdown]
# Putting it together: a schematic CNN on a gray-scale image.

# %% [markdown]
# <img src = "Images/conv_manyfilters.png" />

# %% [markdown]
# Haven't seen subsampling/aggregation/pooling yet.

# %% [markdown]
# Putting it together: a schematic CNN on a color image.

# %% [markdown]
# <img src = "Images/colorcnn.png" >

# %% [markdown]
# Haven't seen subsampling/aggregation/pooling yet.

# %% [markdown]
# #### Subsampling/aggregation: pooling layers
#
# - Pooling performs aggregation within window.
# - Stride pooling window across input.
# - Returns reduced representation.
#
#
# *Most common aggregation*: **max pooling**

# %% [markdown]
# <img src = "Images/maxpool.gif" >

# %% [markdown]
# **Intuition behind max pooling**
# - Reducing representation size.
# - Max: selecting on most distinctive feature.
# - Makes insensitive to translation/rotation of features.

# %% [markdown]
# <img src = "Images/maxpool.gif" >

# %% [markdown]
# <center><img src = "Images/translation_invariance_maxpool.jpg" ></center>

# %% [markdown]
# Repeated convolution/pooling:
# - Creates smaller feature maps laterally but more of them.
# - Encodes higher level features and condenses info.

# %% [markdown]
# <img src = "Images/conv_with_pooling_network.jpeg" >

# %% [markdown]
# Final steps involves flattening/connecting to dense fully-connected network:
# - take high level condensed features.
# - learn correct combinations of them.
# - put into sigmoid/softmax

# %% [markdown]
# <img src = "Images/conv_with_pooling_network.jpeg" >

# %% [markdown]
# Apply this to the MNIST digit recognition problem:

# %% [markdown]
# Some old imports:

# %%
from tensorflow.keras import datasets
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import Dense # creates densely connected layer object
from tensorflow.keras.layers import Flatten # takes 2D input and turns into 1D array
# Out:
# 2023-03-22 09:17:30.941838: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# The new layers

# %%
from tensorflow.keras.layers import Conv2D # convolution layer
from tensorflow.keras.layers import MaxPooling2D # max pooling layer

# %% [markdown]
# Load MNIST

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
train_labels = to_categorical(train_labels)

# %% [markdown]
# Conv2D takes tensors of shape:
# - (image_height, image_width, color_channels) for each image
# - MNIST has one color channel (grayscale).

# %%
train_images = train_images.reshape((60000, 28, 28, 1))
test_images = test_images.reshape((10000, 28, 28, 1))

# %%
train_images.shape
train_labels.shape
# Out:
# (60000, 10)

# %% [markdown]
# Normalize data

# %%
# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255, test_images / 255

# %% [markdown]
# Create the CNN sequential model.

# %%
model = Sequential()
# define 3x3 filter window sizes. Create 32 filters.
# COv2D input shape =(image_height, image_width, color_channels) for each image
model.add(Conv2D(filters=32,
                        kernel_size=(3, 3),
                        activation='relu',
                        input_shape=(28, 28, 1)))
# max pool in 2x2 window
model.add(MaxPooling2D(pool_size=(2, 2)))
# define 3x3 filter window sizes. Create 64 filters.
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))

# transition to dense fully-connected part of network
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))
# Out:
# 2023-03-22 09:17:34.286817: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Let display the architecture of our model so far.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 64)          36928
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 64)                36928
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 93,322
# Trainable params: 93,322
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Compile and train the model

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history_cnn = model.fit(train_images, train_labels, epochs= 20, validation_split = 0.2, batch_size=32, verbose = 2)
# Out:
# Epoch 1/20
# 1500/1500 - 12s - loss: 0.1650 - accuracy: 0.9488 - val_loss: 0.0648 - val_accuracy: 0.9807 - 12s/epoch - 8ms/step
# Epoch 2/20
# 1500/1500 - 11s - loss: 0.0514 - accuracy: 0.9839 - val_loss: 0.0525 - val_accuracy: 0.9842 - 11s/epoch - 8ms/step
# Epoch 3/20
# 1500/1500 - 11s - loss: 0.0366 - accuracy: 0.9883 - val_loss: 0.0351 - val_accuracy: 0.9895 - 11s/epoch - 8ms/step
# Epoch 4/20
# 1500/1500 - 12s - loss: 0.0276 - accuracy: 0.9911 - val_loss: 0.0577 - val_accuracy: 0.9832 - 12s/epoch - 8ms/step
# Epoch 5/20
# 1500/1500 - 12s - loss: 0.0214 - accuracy: 0.9932 - val_loss: 0.0359 - val_accuracy: 0.9902 - 12s/epoch - 8ms/step
# Epoch 6/20
# 1500/1500 - 12s - loss: 0.0174 - accuracy: 0.9943 - val_loss: 0.0373 - val_accuracy: 0.9887 - 12s/epoch - 8ms/step
# Epoch 7/20
# 1500/1500 - 12s - loss: 0.0150 - accuracy: 0.9949 - val_loss: 0.0402 - val_accuracy: 0.9887 - 12s/epoch - 8ms/step
# Epoch 8/20
# 1500/1500 - 12s - loss: 0.0120 - accuracy: 0.9963 - val_loss: 0.0395 - val_accuracy: 0.9899 - 12s/epoch - 8ms/step
# Epoch 9/20
# 1500/1500 - 11s - loss: 0.0108 - accuracy: 0.9961 - val_loss: 0.0493 - val_accuracy: 0.9885 - 11s/epoch - 8ms/step
# Epoch 10/20
# 1500/1500 - 12s - loss: 0.0103 - accuracy: 0.9964 - val_loss: 0.0369 - val_accuracy: 0.9902 - 12s/epoch - 8ms/step
# Epoch 11/20
# 1500/1500 - 12s - loss: 0.0076 - accuracy: 0.9974 - val_loss: 0.0428 - val_accuracy: 0.9904 - 12s/epoch - 8ms/step
# Epoch 12/20
# 1500/1500 - 12s - loss: 0.0083 - accuracy: 0.9971 - val_loss: 0.0413 - val_accuracy: 0.9903 - 12s/epoch - 8ms/step
# Epoch 13/20
# 1500/1500 - 13s - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.0458 - val_accuracy: 0.9911 - 13s/epoch - 9ms/step
# Epoch 14/20
# 1500/1500 - 11s - loss: 0.0058 - accuracy: 0.9981 - val_loss: 0.0455 - val_accuracy: 0.9894 - 11s/epoch - 8ms/step
# Epoch 15/20
# 1500/1500 - 11s - loss: 0.0070 - accuracy: 0.9980 - val_loss: 0.0651 - val_accuracy: 0.9867 - 11s/epoch - 8ms/step
# Epoch 16/20
# 1500/1500 - 11s - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.0521 - val_accuracy: 0.9903 - 11s/epoch - 8ms/step
# Epoch 17/20
# 1500/1500 - 11s - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.0478 - val_accuracy: 0.9906 - 11s/epoch - 8ms/step
# Epoch 18/20
# 1500/1500 - 11s - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.0549 - val_accuracy: 0.9908 - 11s/epoch - 8ms/step
# Epoch 19/20
# 1500/1500 - 11s - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.0531 - val_accuracy: 0.9905 - 11s/epoch - 8ms/step
# Epoch 20/20
# 1500/1500 - 12s - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.0550 - val_accuracy: 0.9915 - 12s/epoch - 8ms/step

# %% [markdown]
# #### Evaluate the model

# %%
_, test_acc = model.evaluate(test_images, to_categorical(test_labels), verbose =2)
# Out:
# 313/313 - 1s - loss: 0.0485 - accuracy: 0.9915 - 972ms/epoch - 3ms/step

# %%
print(test_acc)
# Out:
# 0.9915000200271606

# %%
train_cnn_history = pd.DataFrame(history_cnn.history)
train_cnn_history.index.name = 'epochs'

col_list = ['loss', 'val_loss']
train_cnn_history[col_list].plot()
plt.ylabel('Categorical cross entropy')
plt.title('Training loss history')
plt.show()

# %%
col_list = ['accuracy', 'val_accuracy']
train_cnn_history[col_list].plot()
plt.ylabel('Accuracy')
plt.title('Training loss history')
plt.show()

# %% [markdown]
# Overfitting has occurred: further training is not improving the validation scores in anyway.

# %% [markdown]
# Can we improve this by regularization techniques?
# - typically we add dropout and L2 regularization after the convolutional layers

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Dropout

# a new layer that rescales/normalizes the activations after each layer.
# has a weak regularization effect. also allows 

from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Activation

# %%
model2 = Sequential()
# define 3x3 filter window sizes. Create 32 filters.
model2.add(Conv2D(filters=32,
                        kernel_size=(3, 3),
                        activation='relu',
                        input_shape=(28, 28, 1), kernel_regularizer = l2(5e-4) ))

model2.add(BatchNormalization())
# max pool in 2x2 window
model2.add(MaxPooling2D(pool_size=(2, 2)))
# define 3x3 filter window sizes. Create 64 filters.
model2.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer = l2(5e-4) ))

model2.add(BatchNormalization())
model2.add(MaxPooling2D((2, 2)))
model2.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer = l2(5e-4)))

model2.add(BatchNormalization())

# transition to dense fully-connected part of network
model2.add(Flatten())
model2.add(Dense(256, activation='relu'))
model2.add(Dropout(0.2))

model2.add(BatchNormalization())
model2.add(Dense(128, activation='relu'))
model2.add(Dropout(0.25))

model2.add(BatchNormalization())
model2.add(Dense(64, activation='relu'))
model2.add(Dropout(0.25))
model2.add(Dense(10, activation='softmax'))

model2.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history_reg = model2.fit(train_images, train_labels, epochs= 50, validation_split = 0.2, batch_size=64)
# Out:
# Epoch 1/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.2788 - accuracy: 0.9351 - val_loss: 0.1194 - val_accuracy: 0.9819
# Epoch 2/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.1311 - accuracy: 0.9789 - val_loss: 0.0994 - val_accuracy: 0.9856
# Epoch 3/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.1082 - accuracy: 0.9835 - val_loss: 0.1071 - val_accuracy: 0.9837
# Epoch 4/50
# 750/750 [==============================] - 13s 18ms/step - loss: 0.0943 - accuracy: 0.9866 - val_loss: 0.1028 - val_accuracy: 0.9823
# Epoch 5/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0849 - accuracy: 0.9876 - val_loss: 0.0822 - val_accuracy: 0.9885
# Epoch 6/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0794 - accuracy: 0.9885 - val_loss: 0.0906 - val_accuracy: 0.9857
# Epoch 7/50
# 750/750 [==============================] - 12s 17ms/step - loss: 0.0776 - accuracy: 0.9886 - val_loss: 0.0753 - val_accuracy: 0.9898
# Epoch 8/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0765 - accuracy: 0.9890 - val_loss: 0.0765 - val_accuracy: 0.9896
# Epoch 9/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0701 - accuracy: 0.9901 - val_loss: 0.1061 - val_accuracy: 0.9825
# Epoch 10/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0692 - accuracy: 0.9907 - val_loss: 0.0872 - val_accuracy: 0.9863
# Epoch 11/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0671 - accuracy: 0.9907 - val_loss: 0.0778 - val_accuracy: 0.9893
# Epoch 12/50
# 750/750 [==============================] - 13s 18ms/step - loss: 0.0630 - accuracy: 0.9912 - val_loss: 0.0789 - val_accuracy: 0.9891
# Epoch 13/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0651 - accuracy: 0.9914 - val_loss: 0.0687 - val_accuracy: 0.9910
# Epoch 14/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0581 - accuracy: 0.9925 - val_loss: 0.0698 - val_accuracy: 0.9903
# Epoch 15/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0600 - accuracy: 0.9924 - val_loss: 0.0699 - val_accuracy: 0.9901
# Epoch 16/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0579 - accuracy: 0.9927 - val_loss: 0.0724 - val_accuracy: 0.9888
# Epoch 17/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0571 - accuracy: 0.9925 - val_loss: 0.0702 - val_accuracy: 0.9895
# Epoch 18/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0553 - accuracy: 0.9926 - val_loss: 0.0763 - val_accuracy: 0.9893
# Epoch 19/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0549 - accuracy: 0.9935 - val_loss: 0.0680 - val_accuracy: 0.9905
# Epoch 20/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0526 - accuracy: 0.9932 - val_loss: 0.0763 - val_accuracy: 0.9882
# Epoch 21/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0511 - accuracy: 0.9933 - val_loss: 0.0803 - val_accuracy: 0.9880
# Epoch 22/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0504 - accuracy: 0.9937 - val_loss: 0.0714 - val_accuracy: 0.9894
# Epoch 23/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0465 - accuracy: 0.9946 - val_loss: 0.0651 - val_accuracy: 0.9910
# Epoch 24/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0520 - accuracy: 0.9931 - val_loss: 0.0672 - val_accuracy: 0.9905
# Epoch 25/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0492 - accuracy: 0.9939 - val_loss: 0.0685 - val_accuracy: 0.9904
# Epoch 26/50
# 750/750 [==============================] - 12s 16ms/step - loss: 0.0459 - accuracy: 0.9939 - val_loss: 0.0636 - val_accuracy: 0.9913
# Epoch 27/50
# 750/750 [==============================] - 12s 16ms/step - loss: 0.0477 - accuracy: 0.9939 - val_loss: 0.0773 - val_accuracy: 0.9893
# Epoch 28/50
# 750/750 [==============================] - 12s 17ms/step - loss: 0.0467 - accuracy: 0.9945 - val_loss: 0.0643 - val_accuracy: 0.9919
# Epoch 29/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0437 - accuracy: 0.9949 - val_loss: 0.0680 - val_accuracy: 0.9907
# Epoch 30/50
# 750/750 [==============================] - 12s 17ms/step - loss: 0.0470 - accuracy: 0.9938 - val_loss: 0.0715 - val_accuracy: 0.9898
# Epoch 31/50
# 750/750 [==============================] - 12s 17ms/step - loss: 0.0453 - accuracy: 0.9944 - val_loss: 0.0712 - val_accuracy: 0.9914
# Epoch 32/50
# 750/750 [==============================] - 12s 16ms/step - loss: 0.0432 - accuracy: 0.9950 - val_loss: 0.0645 - val_accuracy: 0.9919
# Epoch 33/50
# 750/750 [==============================] - 12s 16ms/step - loss: 0.0442 - accuracy: 0.9944 - val_loss: 0.0592 - val_accuracy: 0.9918
# Epoch 34/50
# 750/750 [==============================] - 12s 17ms/step - loss: 0.0439 - accuracy: 0.9945 - val_loss: 0.0672 - val_accuracy: 0.9911
# Epoch 35/50
# 750/750 [==============================] - 12s 17ms/step - loss: 0.0449 - accuracy: 0.9946 - val_loss: 0.0653 - val_accuracy: 0.9903
# Epoch 36/50
# 750/750 [==============================] - 12s 17ms/step - loss: 0.0397 - accuracy: 0.9956 - val_loss: 0.0666 - val_accuracy: 0.9916
# Epoch 37/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0420 - accuracy: 0.9947 - val_loss: 0.0733 - val_accuracy: 0.9894
# Epoch 38/50
# 750/750 [==============================] - 12s 17ms/step - loss: 0.0424 - accuracy: 0.9952 - val_loss: 0.0706 - val_accuracy: 0.9877
# Epoch 39/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0397 - accuracy: 0.9958 - val_loss: 0.0655 - val_accuracy: 0.9914
# Epoch 40/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0385 - accuracy: 0.9956 - val_loss: 0.0534 - val_accuracy: 0.9933
# Epoch 41/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0419 - accuracy: 0.9949 - val_loss: 0.0569 - val_accuracy: 0.9927
# Epoch 42/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0398 - accuracy: 0.9952 - val_loss: 0.0640 - val_accuracy: 0.9898
# Epoch 43/50
# 750/750 [==============================] - 12s 17ms/step - loss: 0.0366 - accuracy: 0.9959 - val_loss: 0.0740 - val_accuracy: 0.9902
# Epoch 44/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0402 - accuracy: 0.9951 - val_loss: 0.0539 - val_accuracy: 0.9926
# Epoch 45/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0369 - accuracy: 0.9957 - val_loss: 0.0623 - val_accuracy: 0.9916
# Epoch 46/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0384 - accuracy: 0.9956 - val_loss: 0.0579 - val_accuracy: 0.9920
# Epoch 47/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0374 - accuracy: 0.9952 - val_loss: 0.0684 - val_accuracy: 0.9902
# Epoch 48/50
# 750/750 [==============================] - 14s 18ms/step - loss: 0.0364 - accuracy: 0.9960 - val_loss: 0.0602 - val_accuracy: 0.9926
# Epoch 49/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0386 - accuracy: 0.9953 - val_loss: 0.0638 - val_accuracy: 0.9912
# Epoch 50/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0371 - accuracy: 0.9954 - val_loss: 0.0596 - val_accuracy: 0.9904

# %%
_, test2_acc = model2.evaluate(test_images, to_categorical(test_labels))
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0586 - accuracy: 0.9915

# %%
train_regcnn_history = pd.DataFrame(history_reg.history)
train_regcnn_history.index.name = 'epochs'

col_list = ['loss', 'val_loss']
train_regcnn_history[col_list].plot()
plt.ylabel('Categorical cross entropy')
plt.title('Training loss history')
plt.show()

# %%
train_regcnn_history = pd.DataFrame(history_reg.history)
train_regcnn_history.index.name = 'epochs'

col_list = ['accuracy', 'val_accuracy']
train_regcnn_history[col_list].plot()
plt.ylabel('Categorical cross entropy')
plt.title('Training loss history')
plt.show()

# %% [markdown]
# Changing architecture: simple CNN
# - really high test accuracy.
# - slight overfitting but still good.

# %% [markdown]
# To do much better: many orders of magnitude higher complexity to networks
# - very deep networks required
# - need regularization (L2/dropout)
# - other techniques (batchnorm, skip connections, 1D convolutions etc.)

# %% [markdown]
# Many highly successful pre-trained models exist that can be leveraged:
# - VGG16
# - Resnets
# - Inception Networks

# %% [markdown]
# **Or also just need more data.**
